# %%
row_anat = "C:/Users/milen/Desktop/fMRI_BIDS_rhymejudgment/sub-01/anat/sub-01_T1w.nii/highres001.nii" # trzeba zmienic slashe w drugą strone 
from nilearn import plotting
plotting.plot_anat(row_anat)

# %%
preproc =
